# %% [markdown]
# <a href="https://colab.research.google.com/github/MouheebSA/firstProject/blob/main/SpellingArabicWord.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate random data
np.random.seed(42)
X = np.random.rand(100, 5)  # 100 samples, 5 features
y = np.random.rand(100)     # 100 target values

# Fit a linear regression model
LR = LinearRegression()
LR.fit(X, y)

# Predict the target values
yhat = LR.predict(X)

# Create a scatter plot of the predicted values
plt.scatter(range(len(yhat)), yhat, color='blue', label='Predicted Values')
plt.xlabel('Sample Index')
plt.ylabel('Predicted Value')
plt.title('Scatter Plot of Predicted Values')
plt.legend()
plt.show()

# %%
arabic_words = [
    "تفاحة",
    "ماء",
    "شمس",
    # Add more Arabic words here
]

# Define the mapping of Arabic letters to their corresponding English equivalents
letters_mapping = {
    'ت': 'Tā',
    'ف': 'Fā',
    'ا': 'Alif',
    'ح': 'Ḥā',
    'ة': 'Tā marbūṭa',
    # Add more letter mappings here
}

# Iterate through each Arabic word
for arabic_word in arabic_words:
    spelled_letters = []

    # Spell out each letter of the Arabic word
    for letter in arabic_word:
        spelled_letter = letters_mapping.get(letter, letter)
        spelled_letters.append(spelled_letter)

    # Join the spelled letters into a single string
    spelled_word = ' '.join(spelled_letters)

    # Print the spelled-out word
    print(spelled_word)
# Out:
# Tā Fā Alif Ḥā Tā marbūṭa
# م Alif ء
# ش م س

# %%
arabic_words = [
    "تفاحة",
    "ماء",
    "شمس",
    # Add more Arabic words here
]

# Define the mapping of Arabic letters to their corresponding English equivalents
letters_mapping = {
    'ت': 'T',
    'ف': 'f',
    'ا': 'a',
    'ح': 'h',
    'ة': 'a',
    # Add more letter mappings here
}

# Iterate through each Arabic word
for arabic_word in arabic_words:
    spelled_word = ""

    # Spell out each letter of the Arabic word
    for letter in arabic_word:
        spelled_letter = letters_mapping.get(letter, letter)
        spelled_word += spelled_letter

    # Print the spelled-out word
    print(spelled_word)
# Out:
# Tfaha
# مaء
# شمس

# %%
# Define the mapping of Arabic letters to their corresponding English equivalents
letters_mapping = {
    'ا': 'a',
    'ب': 'b',
    'ت': 't',
    'ث': 'th',
    'ج': 'j',
    'ح': 'h',
    'خ': 'kh',
    'د': 'd',
    'ذ': 'th',
    'ر': 'r',
    'ز': 'z',
    'س': 's',
    'ش': 'sh',
    'ص': 's',
    'ض': 'd',
    'ط': 't',
    'ظ': 'th',
    'ع': 'a',
    'غ': 'gh',
    'ف': 'f',
    'ق': 'q',
    'ك': 'k',
    'ل': 'l',
    'م': 'm',
    'ن': 'n',
    'ه': 'h',
    'و': 'w',
    'ي': 'y',
}

# Get the input Arabic word
arabic_word = input("Enter an Arabic word: ")

# Convert the Arabic word to its spelled-out form
spelled_word = ""

# Spell out each letter of the Arabic word
for letter in arabic_word:
    spelled_letter = letters_mapping.get(letter, letter)
    spelled_word += spelled_letter

# Print the spelled-out word
print(spelled_word)
# Out:
# Enter an Arabic word: ممتع
# mmta

# %%
import csv

# Define the mapping of Arabic letters to their corresponding English equivalents
letters_mapping = {
    'ا': 'a',
    'ب': 'b',
    'ت': 't',
    'ث': 'th',
    'ج': 'j',
    'ح': 'h',
    'خ': 'kh',
    'د': 'd',
    'ذ': 'th',
    'ر': 'r',
    'ز': 'z',
    'س': 's',
    'ش': 'sh',
    'ص': 's',
    'ض': 'd',
    'ط': 't',
    'ظ': 'th',
    'ع': 'a',
    'غ': 'gh',
    'ف': 'f',
    'ق': 'q',
    'ك': 'k',
    'ل': 'l',
    'م': 'm',
    'ن': 'n',
    'ه': 'h',
    'و': 'w',
    'ي': 'y',
    'ة': 'h',
    'ء': 'a',
    'ى': 'a',
}

csv_file = '/content/DistName.csv'

with open(csv_file, 'r', encoding='utf-8') as file:
    reader = csv.reader(file)
    # Skip the header row if present
    next(reader)

    # Iterate through each row in the CSV file
    for row in reader:
        arabic_word = row[0]  # Assuming the Arabic word is in the first column

        # Convert the Arabic word to its spelled-out form
        spelled_word = ""

        # Spell out each letter of the Arabic word
        for letter in arabic_word:
            spelled_letter = letters_mapping.get(letter, letter)
            spelled_word += spelled_letter

        # Print the original Arabic word and its spelled-out form
        print(f"Arabic Word: {arabic_word}")
        print(f"Spelled Word: {spelled_word}")
        print()
# Out:
# Arabic Word: العنبة
# Spelled Word: alanbh
#
# Arabic Word: منبوقه
# Spelled Word: mnbwqh
#
# Arabic Word: الميفاء
# Spelled Word: almyfaa
#
# Arabic Word: ام النصايب
# Spelled Word: am alnsayb
#
# Arabic Word: رديس الغربية
# Spelled Word: rdys alghrbyh
#
# Arabic Word: مركز عواضة
# Spelled Word: mrkz awadh
#
# Arabic Word: العليليه
# Spelled Word: alalylyh
#
# Arabic Word: مزرعة فلاج بن معيطين
# Spelled Word: mzrah flaj bn maytyn
#
# Arabic Word: حضن العير
# Spelled Word: hdn alayr
#
# Arabic Word: الكرى
# Spelled Word: alkra
#
# Arabic Word: ام خيافين
# Spelled Word: am khyafyn
#
# Arabic Word: ربه
# Spelled Word: rbh
#
# Arabic Word: الفرعه
# Spelled Word: alfrah
#
# Arabic Word: رحقان
# Spelled Word: rhqan
#
# Arabic Word: الفرده
# Spelled Word: alfrdh
#
# Arabic Word: الصفا الشرقي
# Spelled Word: alsfa alshrqy

# %%
import csv

# Define the mapping of Arabic letters to their corresponding English equivalents
letters_mapping = {
    'ا': 'a',
    'أ': 'a',
    'إ': 'i',
    'آ': 'a',
    'ب': 'b',
    'ت': 't',
    'ث': 'th',
    'ج': 'j',
    'ح': 'h',
    'خ': 'kh',
    'د': 'd',
    'ذ': 'th',
    'ر': 'r',
    'ز': 'z',
    'س': 's',
    'ش': 'sh',
    'ص': 's',
    'ض': 'd',
    'ط': 't',
    'ظ': 'th',
    'ع': 'a',
    'غ': 'gh',
    'ف': 'f',
    'ق': 'q',
    'ك': 'k',
    'ل': 'l',
    'م': 'm',
    'ن': 'n',
    'ه': 'h',
    'و': 'w',
    'ي': 'y',
    'ة': 'h',
    'ء': 'a',
    'ى': 'a',
    'ئ': 'i',
}

# Read the CSV file containing Arabic words
input_csv_file = '/content/DistArName.csv'
output_csv_file = '/content/DistEN_Name.csv'

with open(input_csv_file, 'r', encoding='utf-8') as input_file, open(output_csv_file, 'w', encoding='utf-8', newline='') as output_file:
    reader = csv.reader(input_file)
    writer = csv.writer(output_file)
    header = next(reader)

    # Add a new column header for the spelled-out word
    header.append('Spelled Word')
    writer.writerow(header)

    # Iterate through each row in the CSV file
    for row in reader:
        arabic_word = row[2]  # Assuming the Arabic word is in the first column

        # Convert the Arabic word to its spelled-out form
        spelled_word = ""

        # Spell out each letter of the Arabic word
        for letter in arabic_word:
            spelled_letter = letters_mapping.get(letter, letter)
            spelled_word += spelled_letter

        # Write the original Arabic word and its spelled-out form to the output CSV file
        row.append(spelled_word)
        writer.writerow(row)
